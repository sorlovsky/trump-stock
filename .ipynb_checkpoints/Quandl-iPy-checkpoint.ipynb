# %%
import quandl
import matplotlib.pyplot as plt
import pandas
import numpy

# %%
UTX = quandl.get("WIKI/UTX", start_date="2016-12-31", end_date="2017-5-01")
# print(mydata)
plt.plot(UTX)
plt.show()

# %%
print(type(UTX))
# Out:
# <class 'pandas.core.frame.DataFrame'>
