# %%
import quandl
quandl.ApiConfig.api_key = "mwbHy7C9x4U5HWdxhM9i"

import matplotlib.pyplot as plt
import pandas
import numpy
import nltk

# %%
data = quandl.get('WIKI/AET', start_date="2017-03-28", end_date="2017-03-29")

# %%
print(type(data))
data["Close"]
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
