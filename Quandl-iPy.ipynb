# %%
import quandl
quandl.ApiConfig.api_key = "mwbHy7C9x4U5HWdxhM9i"


import matplotlib.pyplot as plt
import pandas
import numpy
import nltk

# %%
data = quandl.get('WIKI/TM', start_date="2016-12-31", end_date="2017-1-31")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-35-92c609c72d49> in <module>()
# ----> 1 data = quandl.get('WIKI/TM', start_date="2016-12-31", end_date="2017-1-31")
#
# /usr/local/lib/python3.5/site-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /usr/local/lib/python3.5/site-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
# ...

# %%
print(type(data))
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               Open    High       Low   Close      Volume  Ex-Dividend  \
# Date
# 2017-01-03  116.03  117.84  115.5100  116.86  20663912.0          0.0
# 2017-01-04  117.55  119.66  117.2900  118.69  19630932.0          0.0
# 2017-01-05  118.86  120.95  118.3209  120.67  19492150.0          0.0
# 2017-01-06  120.98  123.88  120.0300  123.41  28545263.0          0.0
# 2017-01-09  123.55  125.43  123.0400  124.90  22880360.0          0.0
# 2017-01-10  124.82  125.50  124.2800  124.35  17324590.0          0.0
# 2017-01-11  124.35  126.12  124.0600  126.09  18356523.0          0.0
# 2017-01-12  125.61  126.73  124.8000  126.62  18653914.0          0.0
# 2017-01-13  127.49  129.27  127.3700  128.34  24884325.0          0.0
# 2017-01-17  128.04  128.34  127.4000  127.87  15294460.0          0.0
# 2017-01-18  128.41  128.43  126.8400  127.92  13145852.0          0.0
# 2017-01-19  128.23  128.35  127.4500  127.55  12195465.0          0.0
# ...
